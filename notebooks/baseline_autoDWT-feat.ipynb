# %%
import numpy as np
np.set_printoptions(threshold=100000, linewidth=100000)
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

# %%
import datetime
def write_csv_file(y_pred :np.ndarray):
    '''Write csv file from numpy array y_pred'''
    now_string = (datetime.datetime.now()-datetime.timedelta(hours=3)).strftime("%d-%m_%H-%M-%S")
    
    output_df = pd.DataFrame([f'CPMG_{i:03d}.csv' for i in range(1000)], columns=['CPMG'])
    output_df['%'] = y_pred#.squeeze().detach().cpu().numpy()
    output_df.to_csv("time2_trilha1_"+now_string+".csv", sep="\t", index=False)
    return output_df

# %%
train_df = pd.read_csv('data_train_autoDWTfeat.csv', sep="\t")
test_df = pd.read_csv('data_test_autoDWTfeat.csv', sep="\t")

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X = torch.Tensor(np.array(train_df.iloc[:,:-1])).to(device)
y = torch.Tensor(np.array(train_df['y']).reshape(-1,1)).to(device)

dataset = TensorDataset(X, y)
trainDs, valDs = random_split(dataset, [.8,.2])

train_loader = DataLoader(trainDs, batch_size=256, shuffle=True)
val_loader = DataLoader(valDs, batch_size=256, shuffle=False)

# %%
model = nn.Sequential(
    nn.Linear(X.shape[1],256),
    nn.ReLU(),
    nn.Linear(256,128),
    nn.ReLU(),
    nn.Linear(128,1),
    nn.Sigmoid(),).to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
epochs = 120  #20
history = []
for epoch in range(epochs):
    model.train()
    train_loss = 0.0

    for xb, yb in train_loader:
        pred = model(xb)
        loss = criterion(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)
    train_loss /=len(train_loader.dataset)

    model.eval()
    val_loss = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            val_loss += criterion(pred, yb).item() * xb.size(0)
    val_loss /= len(val_loader.dataset)

    history.append((train_loss, val_loss))

    if epoch%10==0: print(f"Epoch {epoch:02d} | Train MSE: {train_loss:.6f} | Val MSE: {val_loss:.6f}")
plt.plot(range(len(history)), [l[0] for l in history], label='train')
plt.plot(range(len(history)), [l[1] for l in history], label='val')
plt.title('MSE error')
plt.legend()
plt.show()
# Out:
# Epoch 00 | Train MSE: 0.055003 | Val MSE: 0.046917
# Epoch 10 | Train MSE: 0.019722 | Val MSE: 0.021574
# Epoch 20 | Train MSE: 0.012432 | Val MSE: 0.011946
# Epoch 30 | Train MSE: 0.014969 | Val MSE: 0.013981
# Epoch 40 | Train MSE: 0.011855 | Val MSE: 0.015598
# Epoch 50 | Train MSE: 0.011316 | Val MSE: 0.010692
# Epoch 60 | Train MSE: 0.010538 | Val MSE: 0.009744
# Epoch 70 | Train MSE: 0.010032 | Val MSE: 0.009632
# Epoch 80 | Train MSE: 0.009753 | Val MSE: 0.008734
# Epoch 90 | Train MSE: 0.010184 | Val MSE: 0.009660
# Epoch 100 | Train MSE: 0.009837 | Val MSE: 0.009570
# Epoch 110 | Train MSE: 0.009000 | Val MSE: 0.007854

# %%
Xval = valDs.dataset.tensors[0][valDs.indices]#.squeeze().detach().cpu().numpy()
yval = valDs.dataset.tensors[1][valDs.indices].squeeze().detach().cpu().numpy()

model.eval()
with torch.no_grad():
    y_pred = model(Xval).squeeze().detach().cpu().numpy()

# RMSE, R2, MAE
mse = np.mean((y_pred - yval)**2)
mae = np.mean(np.abs((y_pred - yval)))
R2  = 1 - mse/np.std(yval)**2
print("RMSE:", np.sqrt(mse), "R²:", R2, "MAE:", mae)

# Gráfico de avaliação
plt.figure(figsize=(7, 7))
plt.scatter(y_pred, yval, alpha=0.6)

# Reta x = y (ideal)
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())
plt.plot([min_val, max_val], [min_val, max_val], '--')

plt.xlabel("Predição do modelo")
plt.ylabel("Valor real")
plt.title("Avaliação da MLP com DWTfeat: Predito vs Real")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RMSE: 0.08976706 R²: 0.8457982 MAE: 0.07028906

# %%
# write_csv_file(y_pred.squeeze().detach().cpu().numpy())

# %% [markdown]
# ### Fazendo PCA

# %%
train_df = pd.read_csv('data_train_autoDWTfeat.csv', sep="\t")
test_df = pd.read_csv('data_test_autoDWTfeat.csv', sep="\t")

# %%
pca = sklearn.decomposition.PCA(n_components=.95)
pca.fit(train_df.iloc[:,:-1])
# Out:
# PCA(n_components=0.95)

# %%
train_df_pca = pd.DataFrame(pca.transform(train_df.iloc[:,:-1]))
train_df_pca['y'] = train_df['y']
test_df_pca = pd.DataFrame(pca.transform(test_df))
# train_df_pca.to_csv("data_train_PCA.csv", sep="\t")
# test_df_pca.to_csv("data_test_PCA.csv", sep="\t")

# %%
'''Plot graph of test and train after PCA'''
fig, ax = plt.subplots(1,5, figsize=(20,5))
for i in range(5):
    j = np.random.randint(1,1000)
    ax[i].plot(train_df_pca.loc[j].values[:-1])
    ax[i].set_title(f"{j}-th train data, sat oil={train_df_pca.iloc[j,-1]}")
plt.show();

fig, ax = plt.subplots(1,5, figsize=(20,5))
for i in range(5):
    j = np.random.randint(1,1000)
    ax[i].plot(test_df_pca.loc[j].values)
    ax[i].set_title(f"{j}-th test data")
plt.show();

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X = torch.Tensor(np.array(train_df_pca.drop('y',axis=1))).to(device)
y = torch.Tensor(np.array(train_df_pca['y']).reshape(-1,1)).to(device)

dataset = TensorDataset(X, y)
trainDs, valDs = random_split(dataset, [.8,.2])

train_loader = DataLoader(trainDs, batch_size=256, shuffle=True)
val_loader = DataLoader(valDs, batch_size=256, shuffle=False)

# %%
model = nn.Sequential(
    nn.Linear(X.shape[1],256),
    nn.ReLU(),
    nn.Linear(256,128),
    nn.ReLU(),
    nn.Linear(128,1),
    nn.Sigmoid(),).to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
epochs = 75
history = []
for epoch in range(epochs):
    model.train()
    train_loss = 0.0

    for xb, yb in train_loader:
        pred = model(xb)
        loss = criterion(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)
    train_loss /=len(train_loader.dataset)

    model.eval()
    val_loss = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            val_loss += criterion(pred, yb).item() * xb.size(0)
    val_loss /= len(val_loader.dataset)

    history.append((train_loss, val_loss))

    if epoch%5==0: print(f"Epoch {epoch:02d} | Train MSE: {train_loss:.6f} | Val MSE: {val_loss:.6f}")
plt.plot(range(len(history)), [l[0] for l in history], label='train')
plt.plot(range(len(history)), [l[1] for l in history], label='val')
plt.title('MSE error')
plt.legend()
plt.show()
# Out:
# Epoch 00 | Train MSE: 0.052388 | Val MSE: 0.035373
# Epoch 05 | Train MSE: 0.012774 | Val MSE: 0.010515
# Epoch 10 | Train MSE: 0.010895 | Val MSE: 0.009449
# Epoch 15 | Train MSE: 0.010618 | Val MSE: 0.009495
# Epoch 20 | Train MSE: 0.010603 | Val MSE: 0.009576
# Epoch 25 | Train MSE: 0.010601 | Val MSE: 0.009355
# Epoch 30 | Train MSE: 0.010573 | Val MSE: 0.009402
# Epoch 35 | Train MSE: 0.010516 | Val MSE: 0.009672
# Epoch 40 | Train MSE: 0.010572 | Val MSE: 0.009371
# Epoch 45 | Train MSE: 0.010592 | Val MSE: 0.009427
# Epoch 50 | Train MSE: 0.010570 | Val MSE: 0.009339
# Epoch 55 | Train MSE: 0.010622 | Val MSE: 0.009326
# Epoch 60 | Train MSE: 0.010654 | Val MSE: 0.009591
# Epoch 65 | Train MSE: 0.010556 | Val MSE: 0.009437
# Epoch 70 | Train MSE: 0.010526 | Val MSE: 0.009338

# %%
Xval = valDs.dataset.tensors[0][valDs.indices]#.squeeze().detach().cpu().numpy()
yval = valDs.dataset.tensors[1][valDs.indices].squeeze().detach().cpu().numpy()

model.eval()
with torch.no_grad():
    y_pred = model(Xval).squeeze().detach().cpu().numpy()

# RMSE, MAE
rmse = np.sqrt(np.mean((y_pred - yval)**2))
mae = np.mean(np.abs((y_pred - yval)))
print("RMSE:", rmse, "MAE:", mae)

# Gráfico de avaliação
plt.figure(figsize=(7, 7))
plt.scatter(y_pred, yval, alpha=0.6)

# Reta x = y (ideal)
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())
plt.plot([min_val, max_val], [min_val, max_val], '--')

plt.xlabel("Predição do modelo")
plt.ylabel("Valor real")
plt.title("Avaliação da MLP com autoDWTfeat e PCA: Predito vs Real")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RMSE: 0.09693986 MAE: 0.074040845

# %%
Xtest = torch.Tensor(np.array(test_df_pca))
model.eval()
with torch.no_grad():
    ytest_pred = model(Xtest).squeeze().detach().cpu().numpy()

write_csv_file(ytest_pred)
# Out:
#              CPMG         %
# 0    CPMG_000.csv  0.302651
# 1    CPMG_001.csv  0.701934
# 2    CPMG_002.csv  0.180829
# 3    CPMG_003.csv  0.310258
# 4    CPMG_004.csv  0.087673
# ..            ...       ...
# 995  CPMG_995.csv  0.317961
# 996  CPMG_996.csv  0.721957
# 997  CPMG_997.csv  0.197669
# 998  CPMG_998.csv  0.218721
# 999  CPMG_999.csv  0.196269
#
# [1000 rows x 2 columns]

# %% [markdown]
# Agora com CatBoost

# %%
# %pip install catboost

# %% [markdown]
# ## Catboost: training setup

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split

X = np.array(train_df.iloc[:,:-1])
y = np.array(train_df['y'])

Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=.2)
print([s.shape for s in [X,y,Xtrain, Xval, ytrain, yval]])

model = CatBoostRegressor()
model.fit(Xtrain,ytrain, verbose=0, eval_set=(Xval,yval))
# Out:
# [(1000, 45), (1000,), (800, 45), (200, 45), (800,), (200,)]

# %%
y_pred = model.predict(Xval)

# RMSE, R2, MAE
mse = np.mean((y_pred - yval)**2)
mae = np.mean(np.abs((y_pred - yval)))
R2  = 1 - mse/np.std(yval)**2
print("RMSE:", np.sqrt(mse), "R²:", R2, "MAE:", mae)

# Gráfico de avaliação
plt.figure(figsize=(7, 7))
plt.scatter(y_pred, yval, alpha=0.6)

# Reta x = y (ideal)
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())
plt.plot([min_val, max_val], [min_val, max_val], '--')

plt.xlabel("Predição do modelo")
plt.ylabel("Valor real")
plt.title("Avaliação do CatBoost: Predito vs Real")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RMSE: 0.08673183931076486 R²: 0.8391326738413227 MAE: 0.07052261329788162

# %% [markdown]
# Agora CatBoost no DWTfeat pós-PCA

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split

X = np.array(train_df_pca.iloc[:,:-1])
y = np.array(train_df_pca['y'])

Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=.2)
print([s.shape for s in [X,y,Xtrain, Xval, ytrain, yval]])

model = CatBoostRegressor()
model.fit(Xtrain,ytrain, verbose=0, eval_set=(Xval,yval))
# Out:
# [(1000, 2), (1000,), (800, 2), (200, 2), (800,), (200,)]

# %%
y_pred = model.predict(Xval)

# RMSE, R2, MAE
mse = np.mean((y_pred - yval)**2)
mae = np.mean(np.abs((y_pred - yval)))
R2  = 1 - mse/np.std(yval)**2
print("RMSE:", np.sqrt(mse), "R²:", R2, "MAE:", mae)

# Gráfico de avaliação
plt.figure(figsize=(7, 7))
plt.scatter(y_pred, yval, alpha=0.6)

# Reta x = y (ideal)
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())
plt.plot([min_val, max_val], [min_val, max_val], '--')

plt.xlabel("Predição do modelo")
plt.ylabel("Valor real")
plt.title("Avaliação do CatBoost: Predito vs Real")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RMSE: 0.11394391090239227 R²: 0.7517266818220144 MAE: 0.09041713883510566

# %%
Xtest = np.array(short_test_df.iloc[:,:-1])
write_csv_file(model.predict(Xtest))

# %% [markdown]
# ## Agora uma CNN, por favor

# %%
train_df = pd.read_csv('data_train_autoDWTfeat.csv', sep="\t")
test_df = pd.read_csv('data_test_autoDWTfeat.csv', sep="\t")

# %%
X = torch.Tensor(np.array(train_df)[:,:-1]).unsqueeze(1).to(device)
y = torch.Tensor(np.array(train_df['y']).reshape(-1,1)).to(device)

dataset = TensorDataset(X, y)
trainDs, valDs = random_split(dataset, [.8,.2])

train_loader = DataLoader(trainDs, batch_size=256, shuffle=True)
val_loader = DataLoader(valDs, batch_size=256, shuffle=False)

# %%
model = nn.Sequential(
    nn.Conv1d(1,4,5),
    nn.ReLU(),
    nn.MaxPool1d(2),

    nn.Conv1d(4,16,5),
    nn.ReLU(),
    nn.MaxPool1d(2),

    nn.Conv1d(16,4,5),
    nn.ReLU(),
    nn.MaxPool1d(2),
    
    nn.Flatten(),
    nn.Linear(8,64),
    nn.ReLU(),

    nn.Linear(64,16),
    nn.ReLU(),
        
    nn.Linear(16,1),
    nn.Sigmoid()
).to(device)

#to get the size right in the linear layer
# x = torch.randn(1000, 1, 2201)
# out = model(X)
# print(out.shape)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
epochs = 110
history = []
for epoch in range(epochs):
    model.train()
    train_loss = 0.0

    for xb, yb in train_loader:
        pred = model(xb)
        loss = criterion(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)
    train_loss /=len(train_loader.dataset)

    model.eval()
    val_loss = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            val_loss += criterion(pred, yb).item() * xb.size(0)
    val_loss /= len(val_loader.dataset)

    history.append((train_loss, val_loss))

    if (epoch+1)%5==0: print(f"Epoch {epoch:02d} | Train MSE: {train_loss:.6f} | Val MSE: {val_loss:.6f}")
plt.plot(range(len(history)), [l[0] for l in history], label='train')
plt.plot(range(len(history)), [l[1] for l in history], label='val')
plt.title('MSE error')
plt.legend()
plt.show()
# Out:
# Epoch 04 | Train MSE: 0.009217 | Val MSE: 0.009833
# Epoch 09 | Train MSE: 0.009684 | Val MSE: 0.008971
# Epoch 14 | Train MSE: 0.008755 | Val MSE: 0.008875
# Epoch 19 | Train MSE: 0.008912 | Val MSE: 0.009165
# Epoch 24 | Train MSE: 0.008969 | Val MSE: 0.008380
# Epoch 29 | Train MSE: 0.008224 | Val MSE: 0.008243
# Epoch 34 | Train MSE: 0.008085 | Val MSE: 0.008144
# Epoch 39 | Train MSE: 0.008186 | Val MSE: 0.007949
# Epoch 44 | Train MSE: 0.007873 | Val MSE: 0.007993
# Epoch 49 | Train MSE: 0.008600 | Val MSE: 0.008445
# Epoch 54 | Train MSE: 0.008329 | Val MSE: 0.008044
# Epoch 59 | Train MSE: 0.007791 | Val MSE: 0.007789
# Epoch 64 | Train MSE: 0.007621 | Val MSE: 0.007740
# Epoch 69 | Train MSE: 0.008446 | Val MSE: 0.007854
# Epoch 74 | Train MSE: 0.007812 | Val MSE: 0.008734
# Epoch 79 | Train MSE: 0.007692 | Val MSE: 0.007857
# Epoch 84 | Train MSE: 0.007989 | Val MSE: 0.007575
# Epoch 89 | Train MSE: 0.007547 | Val MSE: 0.007623
# Epoch 94 | Train MSE: 0.007509 | Val MSE: 0.007561
# Epoch 99 | Train MSE: 0.007728 | Val MSE: 0.008003
# Epoch 104 | Train MSE: 0.007591 | Val MSE: 0.007822
# Epoch 109 | Train MSE: 0.007572 | Val MSE: 0.007740

# %%
Xval = valDs.dataset.tensors[0][valDs.indices]#.squeeze().detach().cpu().numpy()
yval = valDs.dataset.tensors[1][valDs.indices].squeeze().detach().cpu().numpy()

model.eval()
with torch.no_grad():
    y_pred = model(Xval).squeeze().detach().cpu().numpy()

# RMSE, R2, MAE
mse = np.mean((y_pred - yval)**2)
mae = np.mean(np.abs((y_pred - yval)))
R2  = 1 - mse/np.std(yval)**2
print("RMSE:", np.sqrt(mse), "R²:", R2, "MAE:", mae)

# Gráfico de avaliação
plt.figure(figsize=(5, 5))
plt.scatter(yval, y_pred, alpha=0.6)

# Reta x = y (ideal)
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())
plt.plot([min_val, max_val], [min_val, max_val], '--')

plt.xlabel("Predição do modelo")
plt.ylabel("Valor real")
plt.title("Avaliação da CNN: Predito vs Real")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RMSE: 0.08797578 R²: 0.84686816 MAE: 0.07186966

# %% [markdown]
# ## RNN: GRU

# %%
train_df = pd.read_csv('data_train_DWTfeat.csv', sep="\t")
test_df = pd.read_csv('data_test_DWTfeat.csv', sep="\t")

# %%
X = torch.Tensor(np.array(train_df)[:,:-1]).unsqueeze(2)
y = torch.Tensor(np.array(train_df['y']).reshape(-1,1))

dataset = TensorDataset(X, y)
trainDs, valDs = random_split(dataset, [.8,.2])

train_loader = DataLoader(trainDs, batch_size=256, shuffle=True)
val_loader = DataLoader(valDs, batch_size=256, shuffle=False)
X.shape

# %%
hidden_size = 16
gru = nn.GRU(input_size=1, hidden_size=hidden_size, num_layers=2, batch_first=True)
head = nn.Linear(hidden_size, 1)   # prediction head

# combine params from both "submodules"
optimizer = torch.optim.Adam(list(gru.parameters()) + list(head.parameters()), lr=1e-3)
criterion = nn.MSELoss()

# %%
# ----- training loop -----
gru.train(); head.train()
loss_history = []
for epoch in range(10):
    train_loss = 0.0
    for xb, yb in train_loader:
        # forward (manual “forward”)
        out, h = gru(xb)               # out: (B, T, H), h: (1, B, H)
        feat = out[:, -1, :]           # OR: h[-1]  (both are (B, H))
        pred = torch.sigmoid(head(feat))  # keep in [0,1]

        loss = criterion(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)
        
    loss_history.append(train_loss/len(train_loader.dataset))
    print(f"epoch {epoch+1:02d} | train MSE: {train_loss/len(train_loader.dataset):.6f}")
plt.plot(loss_history);

# %%
# ----- inference -----
gru.eval(); head.eval()
val_loss = 0
with torch.no_grad():
    for xb, yb in val_loader:
        out, h = gru(xb)
        feat = out[:, -1, :]
        y_pred = torch.sigmoid(head(feat))
        val_loss += criterion(y_pred, yb).item() * xb.size(0)
val_loss /= len(val_loader.dataset)

# RMSE, MAE
rmse = np.sqrt(np.mean((y_pred.squeeze().detach().cpu().numpy() - yval.reshape(-1,1))**2))
mae = np.mean(np.abs((y_pred.squeeze().detach().cpu().numpy() - yval.reshape(-1,1))))
print("RMSE:", rmse, "MAE:", mae)

# Gráfico de avaliação
plt.figure(figsize=(5, 5))
plt.scatter(yval, y_pred, alpha=0.6)

# Reta x = y (ideal)
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())
plt.plot([min_val, max_val], [min_val, max_val], '--')

plt.xlabel("Predição do modelo")
plt.ylabel("Valor real")
plt.title("Avaliação da GRU (RNN): Predito vs Real")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Horrível, algo deu errado aqui

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import train_test_split

X = np.array(train_df.iloc[:,:-1])
y = np.array(train_df['y'])

Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=.2)
print([s.shape for s in [X,y,Xtrain, Xval, ytrain, yval]])
# Out:
# [(1000, 45), (1000,), (800, 45), (200, 45), (800,), (200,)]

# %%
model = RFR(n_estimators=100, criterion='squared_error')
model.fit(Xtrain, ytrain)
y_pred, y_tr_pred = model.predict(Xval), model.predict(Xtrain)

# %%
# RMSE, R2, MAE
mse = np.mean((y_pred - yval)**2)
mae = np.mean(np.abs((y_pred - yval)))
R2  = 1 - mse/np.std(yval)**2
print("RMSE:", np.sqrt(mse), "R²:", R2, "MAE:", mae)

# Gráfico de avaliação
fig, (ax0,ax1) = plt.subplots(1,2, figsize=(10, 5))
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())

ax0.scatter(y_pred, yval, alpha=0.6)
ax0.plot([min_val, max_val], [min_val, max_val], '--')
ax0.set_xlabel("Predição do modelo")
ax0.set_ylabel("Valor real")
ax0.set_title("Avaliação do modelo: Predito vs Real")
ax0.grid(True, alpha=0.3)

ax1.scatter(y_tr_pred, ytrain, alpha=0.6)
ax1.plot([min_val, max_val], [min_val, max_val], '--')
ax1.set_xlabel("Predição do modelo")
ax1.set_ylabel("Valor real")
ax1.set_title("Modelo aplicado ao próprio treino: Predito vs Real")
ax1.grid(True, alpha=0.3)

plt.show()
# Out:
# RMSE: 0.08639940972020584 R²: 0.8651183866153698 MAE: 0.06979899999999999

# %% [markdown]
# Resultado fraco

# %% [markdown]
# RandomForestRegressor em cima do PCA das DWTfeatures

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import train_test_split

X = np.array(train_df_pca.iloc[:,:-1])
y = np.array(train_df_pca['y'])

Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=.2)
print([s.shape for s in [X,y,Xtrain, Xval, ytrain, yval]])
# Out:
# [(1000, 3), (1000,), (800, 3), (200, 3), (800,), (200,)]

# %%
model = RFR(n_estimators=100, criterion='squared_error')
model.fit(Xtrain, ytrain)
y_pred, y_tr_pred = model.predict(Xval), model.predict(Xtrain)

# %%
# RMSE, R2, MAE
mse = np.mean((y_pred - yval)**2)
mae = np.mean(np.abs((y_pred - yval)))
R2  = 1 - mse/np.std(yval)**2
print("RMSE:", np.sqrt(mse), "R²:", R2, "MAE:", mae)

# Gráfico de avaliação
fig, (ax0,ax1) = plt.subplots(1,2, figsize=(10, 5))
min_val = min(y_pred.min(), yval.min())
max_val = max(y_pred.max(), yval.max())

ax0.scatter(y_pred, yval, alpha=0.6)
ax0.plot([min_val, max_val], [min_val, max_val], '--')
ax0.set_xlabel("Predição do modelo")
ax0.set_ylabel("Valor real")
ax0.set_title("Avaliação do modelo: Predito vs Real")
ax0.grid(True, alpha=0.3)

ax1.scatter(y_tr_pred, ytrain, alpha=0.6)
ax1.plot([min_val, max_val], [min_val, max_val], '--')
ax1.set_xlabel("Predição do modelo")
ax1.set_ylabel("Valor real")
ax1.set_title("Modelo aplicado ao próprio treino: Predito vs Real")
ax1.grid(True, alpha=0.3)

plt.show()
# Out:
# RMSE: 0.11314147404908603 R²: 0.735888609140516 MAE: 0.09176550000000003
