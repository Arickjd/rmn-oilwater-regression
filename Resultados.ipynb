# %% [markdown]
# ### Resultados
# #### Dia 10/11
#
# | Dados | Preprocessamento | Partição | Modelo | MAE | RMSE (treino) | RMSE (teste) | $R^2$ (teste) |
# |-------|-------------------|----------|---------|------|----------------|----------------|-|
# |train_norm|                   |          |MLP|   |  - |0,1183|                |
# |train_norm|                   |          | MLP_v2|     |- |**0,1013**|                |
# |train_norm|                   |          |Catboost|   |   -|0,1023|        |
#
# #### Dia 11/11
#
# | Dados | Preprocessamento | Partição | Modelo | MAE | RMSE (treino) | RMSE (teste) | $R^2$ (teste)
# |-------|-------------------|----------|---------|------|----------------|----------------|----|
# |train_raw| TSFresh |test_size=0.2|XGBoost|   | 0.081400  |0.12000||
# |train_raw| TSFresh |test_size=0.3| RandomForest|     | 0.8300 |0.1387||
# |train_raw| TSFresh |test_size=0.3|Catboost|   |  0.083039 |---||
# |train_raw| TSFresh |test_size=0.3|MLP (sklearn)|   |   |||
# |train_norm|DWT+PCA |val_size=0.2 |MLP (torch)| 0.062067 |0.0798288| 0.0914| 0.84440|
# |train_raw|DWT+PCA |val_size=0.2 |MLP (torch)| 0.060998 |0.078269| 0.12450 | 0.71100|
# |train_norm|DWT+PCA|val_size=0.2| MLP (torch)| | |0.0919|0.8427|
# |n_post_smooth|DWT+PCA|val_size=0.2| MLP (torch)| 0.070370| **0.090462**|**0.0908**|0.8463|
# |n_post_smooth| TSFresh |test_size=0.3|XGBoost|   | 0.086400  |0.09200||
# |n_post_smooth|DWT|val_size=0.2| RandomForest| 0.073049| 0.091859|0.0969|0.825|
# |n_post_smooth|savgol+PCA|val_size=0.2| MLP (torch)| 0.069852| 0.089593|0.0917|0.8435|
#
# #### Dia 13/11
#
# | Dados | Preprocessamento | Partição | Modelo | MAE | RMSE (treino) | RMSE (teste) | $R^2$ (teste)
# |-------|------------------|----------|--------|-----|---------------|--------------|--------|
# |n_post_smooth| DWT|val_size=0.2| MLP c/ dropout| 0.066729|0.086780|0.0953|0.831|
# |n_post_smooth| DWT+PCA|val_size=0.2| MLP c/ dropout| 0.061471 |0.077682 |0.092|0.8425|
# |n_post_smooth| DWT|val_size=0.2| Physical Informed | - | - | **0.09300** | - |
